# %%
import scipy as sp
import matplotlib.pyplot as plt
from ipywidgets import interact

# %%
def desbalanceamento(rmin, rmax, csi):
    r = sp.linspace(rmin, rmax, 100*(rmax-rmin))
    X = r**2/sp.sqrt((1-r**2)**2+(2*csi*r))
    plt.plot(r, X)
    plt.xlabel('r')
    plt.ylabel('mX/m$_o$e')


def amplitude(wmin, wmax, csi):
    w = sp.linspace(wmin, wmax, 100*(wmax-wmin))
    X = 1/sp.sqrt((1-w**2)**2+(2*csi*w)**2)
    plt.plot(w, X)
    plt.xlabel('w$_f$/w$_n$')
    plt.ylabel('Xw$_n$²/F$_o$')
    
def fase()

# %%
desbalanceamento(rmin=.01, rmax=3., csi=.01)

# %%
interact(desbalanceamento, rmin=.1, rmax=3., csi=(0.01,.25,0.01))
# Out:
# <function __main__.desbalanceamento>

# %%
amplitude(wmin = .1, wmax=3., csi= 0.01)

# %%
interact(amplitude, wmin=.1, wmax=3., csi=(0.01,.7,0.01))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6d749646375a> in <module>()
# ----> 1 interact(amplitude, wmin=.1, wmax=3., csi=(0.01,.7,0.01))
#
# NameError: name 'interact' is not defined
